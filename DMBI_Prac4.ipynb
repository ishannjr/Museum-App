# %%
# Data Visualization and Statistical Data Analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

df = pd.read_csv("diabetes_dataset.csv")

# %%
df.head(10)
# Out:
#    times_pregnant  plasma_concentration  blood_pressure  skin_thickness  \
# 0               6                   148              72              35
# 1               1                    85              66              29
# 2               8                   183              64               0
# 3               1                    89              66              23
# 4               0                   137              40              35
# 5               5                   116              74               0
# 6               3                    78              50              32
# 7              10                   115               0               0
# 8               2                   197              70              45
# 9               8                   125              96               0
#
#    insulin   bmi  pedigree_function  age            class
# 0        0  33.6              0.627   50  tested_positive
# 1        0  26.6              0.351   31  tested_negative
# ...

# %%
df.describe()
# Out:
#        times_pregnant  plasma_concentration  blood_pressure  skin_thickness  \
# count      768.000000            768.000000      768.000000      768.000000
# mean         3.845052            120.894531       69.105469       20.536458
# std          3.369578             31.972618       19.355807       15.952218
# min          0.000000              0.000000        0.000000        0.000000
# 25%          1.000000             99.000000       62.000000        0.000000
# 50%          3.000000            117.000000       72.000000       23.000000
# 75%          6.000000            140.250000       80.000000       32.000000
# max         17.000000            199.000000      122.000000       99.000000
#
#           insulin         bmi  pedigree_function         age
# count  768.000000  768.000000         768.000000  768.000000
# mean    79.799479   31.992578           0.471876   33.240885
# std    115.244002    7.884160           0.331329   11.760232
# ...

# %%
tested_df = df['class']
print(tested_df.value_counts())

# Bar Graph

plt.figure(figsize=(4, 8))
plt.bar(['Tested Negative','Tested Positive'], tested_df.value_counts())
plt.title('Counts of Tested Individuals')
plt.xlabel('Test Results')
plt.ylabel('Count')
# Out:
# tested_negative    500
# tested_positive    268
# Name: class, dtype: int64
# Text(0, 0.5, 'Count')

# %%
# Histogram

plt.figure(figsize=(10,6))
plt.hist(x=df['age'], bins=10, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('No of Records')
# Out:
# Text(0, 0.5, 'No of Records')

# %%
#Scatter plot

plt.figure(figsize=(10, 6))
sb.scatterplot(x=df['bmi'], y=df['age'], hue=df['class'])
plt.xlabel('Age')
plt.ylabel('Body Mass Index')
#plt.scatter(df['age'], df['insulin'])
# Out:
# Text(0, 0.5, 'Body Mass Index')

# %%
# Box Plot

plt.boxplot(df['blood_pressure'])
plt.title('Box Plot - Blood Pressure')
plt.ylabel('Pressure')
# Out:
# Text(0, 0.5, 'Pressure')

# %%
boxplot = df.boxplot(figsize = (10, 8), rot = 90, grid = False)

# %%
# Heatmap

plt.figure(figsize=(10,6))
sb.heatmap(df.corr())

# %%
import pandas as pd
import scipy.stats as stats

# create sample data according to survey
data = [['likes_reading', 'Male'] for i in range(250)] + \
        [['likes_reading', 'Female'] for i in range(200)] + \
        [['disikes_reading', 'Male'] for i in range(50)] + \
        [['disikes_reading', 'Female'] for i in range(1000)]

df = pd.DataFrame(data, columns = ['Reading Status', 'Gender']) 

# create contingency table
data_crosstab = pd.crosstab(df['Reading Status'],
                            df['Gender'],
                           margins=True, margins_name="Total")

# significance level
alpha = 0.001

# Calcualtion of Chisquare test statistics
chi_square = 0
rows = df['Reading Status'].unique()
columns = df['Gender'].unique()
for i in columns:
    for j in rows:
        O = data_crosstab[i][j]
        E = data_crosstab[i]['Total'] * data_crosstab['Total'][j] / data_crosstab['Total']['Total']
        chi_square += (O-E)**2/E

# The p-value approach
        
# The critical value approach
print("\n--------------------------------------------------------------------------------------")
print("Approach: The critical value approach to hypothesis testing in the decision rule")
critical_value = stats.chi2.ppf(1-alpha, (len(rows)-1)*(len(columns)-1))
conclusion = "Failed to reject the null hypothesis."
if chi_square > critical_value:
    conclusion = "Null Hypothesis is rejected."
        
print("chisquare-score is:", chi_square, " and p value is:", critical_value)
print(conclusion)
# Out:
# --------------------------------------------------------------------------------------
# Approach: The critical value approach to hypothesis testing in the decision rule
# chisquare-score is: 507.93650793650795  and p value is: 10.827566170662733
# Null Hypothesis is rejected.

# %%
from numpy import mean
from numpy import std

data1 = [8,8,6,5,7,6]
data2 = [81,80,75,65,91,80]

print('\ndata1: mean=%.3f stdv=%.3f\n' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f\n' % (mean(data2), std(data2)))

sum=0
for (i,j) in zip(data1,data2):
    sum += (i - mean(data1)) * (j - mean(data2))


std1=std(data1)
std2=std(data2)

cor=sum/(len(data1)*(std1)*(std2))

print('Pearsons Correlation Coefficient Value:\t', cor)
# Out:
# data1: mean=6.667 stdv=1.106
#
# data2: mean=78.667 stdv=7.760
#
# Pearsons Correlation Coefficient Value:	 0.6475510597952352
